# %% [markdown]
# # ----------------------*Veriable* ------------------------
#
# *   A variable is a name given to the memory location that can hold a value .It does not hold the
#  value itself . It holds the reference to the memory address which holds the value .
#
# * memory location which store value in the temporary form .
#
# # Identifires -
#     Its a set of rules which define how to take varriables.abs
# * Name should be start with Alphabates .{str, name}
# * variable shouldn't start with numbers .{2_str,8_name}
# * We can't use special symbole (@,#,$..) except _ in variable. and keyword (if, wwhile, continue, pass, for...)
#
# ## Snake case -
#     when we use backspace in variable ex - My_name, school.
# ## pascal case -
#     when we start putting the name of variable with capital latter. ex - Myname, Ball, Str.
# ## camel case -
#     When we start putting the name of varriable with small latter like eBay,iPhone
#
# # Type Casting -
#     When we start putting the name of varriable with small latter like eBay,iPhone
#
# ## Implisite -
#     Aotometically type conversion .
#     add = 30 + 43.9
#
# ## Explicit -
#     When we forcefully change the data type it's called explisit.
#     print(float(a))
# # Print Function -
#     Take the out from input.
# ## Parameters -
#     Input which is use inside a particular function .
# 1. object - Valur/ variable name ex - x = 'python'
# 2. sep() - Used for saparet value of variable output .
# 3. end() - Add a value at the end of output . something we want to add then we use
# 4. file() - both are use in file handaling.
# 5. flush - both are use in file handaling.

# %%
name_='rudresh'
print(name_)
# Out:
# rudresh

# %%
_='rudresh'
print(_)
# Out:
# rudresh

# %% [markdown]
# # Type Casting

# %% [markdown]
# ## Implisite

# %%
47 + 676
# Out:
# 723

# %%
97-142-117996+51422
# Out:
# -66619

# %%
a= 10
b = 20
print(a+b/2)
# Out:
# 20.0

# %%
a= 10
b = 20
print((a+b)/2)
# Out:
# 15.0

# %% [markdown]
# ## Explisit

# %%
a = 20
print(type(a))

b = str(a)
print(type(b))
# Out:
# <class 'int'>
# <class 'str'>

# %%
cast_a = float(a)
print(type(cast_a))
# Out:
# <class 'float'>

# %%
l = 30 
w = str(l)
print(type(w))
# Out:
# <class 'str'>
