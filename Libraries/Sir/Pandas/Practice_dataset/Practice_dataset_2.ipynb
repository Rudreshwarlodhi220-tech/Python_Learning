# %%
import pandas as pd
import numpy as np

# %%
Nike_df = pd.read_csv(r'D:\AI & ML\Libraries\Sir\Pandas\Practice_dataset\Nike_Sales_Uncleaned.csv')
Nike_df
# Out:
#       Order_ID Gender_Category Product_Line      Product_Name Size  \
# 0         2000            Kids     Training       SuperRep Go    M
# 1         2001           Women       Soccer     Tiempo Legend    M
# 2         2002           Women       Soccer       Premier III    M
# 3         2003            Kids    Lifestyle        Blazer Mid    L
# 4         2004            Kids      Running    React Infinity   XL
# ...        ...             ...          ...               ...  ...
# 2495      4495            Kids   Basketball     Kyrie Flytrap   XL
# 2496      4496             Men   Basketball     Kyrie Flytrap    L
# 2497      4497             Men       Soccer     Tiempo Legend    7
# 2498      4498           Women     Training  ZoomX Invincible  NaN
# 2499      4499           Women      Running          Air Zoom    M
#
#       Units_Sold      MRP  Discount_Applied  Revenue  Order_Date  \
# 0            NaN      NaN              0.47      0.0  2024-03-09
# ...

# %% [markdown]
# ## EDA

# %%
Nike_df.dtypes
# Out:
# Order_ID              int64
# Gender_Category      object
# Product_Line         object
# Product_Name         object
# Size                 object
# Units_Sold          float64
# MRP                 float64
# Discount_Applied    float64
# Revenue             float64
# Order_Date           object
# Sales_Channel        object
# Region               object
# Profit              float64
# dtype: object

# %%
Nike_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          2500 non-null   int64
#  1   Gender_Category   2500 non-null   object
#  2   Product_Line      2500 non-null   object
#  3   Product_Name      2500 non-null   object
#  4   Size              1990 non-null   object
#  5   Units_Sold        1265 non-null   float64
#  6   MRP               1246 non-null   float64
#  7   Discount_Applied  832 non-null    float64
#  8   Revenue           2500 non-null   float64
#  9   Order_Date        1884 non-null   object
#  10  Sales_Channel     2500 non-null   object
#  11  Region            2500 non-null   object
#  12  Profit            2500 non-null   float64
# dtypes: float64(5), int64(1), object(7)
# memory usage: 254.0+ KB

# %%
Nike_df.describe()
# Out:
#           Order_ID   Units_Sold          MRP  Discount_Applied       Revenue  \
# count  2500.000000  1265.000000  1246.000000        832.000000   2500.000000
# mean   3194.352400     1.482213  6039.863395          0.631022    274.873716
# std     749.972638     1.696947  2315.746826          0.365500   2023.773550
# min    2000.000000    -1.000000  2006.630000          0.000000  -7561.590000
# 25%    2534.750000     0.000000  4038.902500          0.320000      0.000000
# 50%    3192.500000     2.000000  6110.030000          0.615000      0.000000
# 75%    3841.250000     3.000000  8022.187500          0.962500      0.000000
# max    4499.000000     4.000000  9996.220000          1.250000  37169.350000
#
#             Profit
# count  2500.000000
# mean   1376.012848
# std    1478.671013
# min   -1199.450000
# 25%      93.532500
# 50%    1371.385000
# 75%    2660.645000
# max    3999.210000

# %%
Nike_df.isnull().sum()
# Out:
# Order_ID               0
# Gender_Category        0
# Product_Line           0
# Product_Name           0
# Size                 510
# Units_Sold          1235
# MRP                 1254
# Discount_Applied    1668
# Revenue                0
# Order_Date           616
# Sales_Channel          0
# Region                 0
# Profit                 0
# dtype: int64

# %%
Nike_df.select_dtypes(include = 'number')
# Out:
#       Order_ID  Units_Sold      MRP  Discount_Applied  Revenue   Profit
# 0         2000         NaN      NaN              0.47      0.0  -770.45
# 1         2001         3.0  4957.93               NaN      0.0  -112.53
# 2         2002         4.0      NaN               NaN      0.0  3337.34
# 3         2003         NaN  9673.57               NaN      0.0  3376.85
# 4         2004         NaN      NaN               NaN      0.0   187.89
# ...        ...         ...      ...               ...      ...      ...
# 2495      4495         3.0      NaN               NaN      0.0     2.97
# 2496      4496        -1.0      NaN               NaN      0.0  -487.36
# 2497      4497         NaN  6647.60              0.52      0.0  -918.14
# 2498      4498         4.0  5358.70               NaN      0.0  3352.29
# 2499      4499         NaN  5550.99               NaN      0.0  2453.57
#
# [2500 rows x 6 columns]

# %%
Nike_df.select_dtypes(include='number').columns
# Out:
# Index(['Order_ID', 'Units_Sold', 'MRP', 'Discount_Applied', 'Revenue',
#        'Profit'],
#       dtype='object')

# %%
col_list = ['Units_Sold', 'MRP', 'Discount_Applied', 'Revenue','Profit']

for i in col_list:
    Nike_df[i].fillna(Nike_df[i].mean(),inplace=True)
# Out:
# C:\Users\Harsh\AppData\Local\Temp\ipykernel_19860\877171095.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Nike_df[i].fillna(Nike_df[i].mean(),inplace=True)

# %%
Nike_df.isnull().sum()
# Out:
# Order_ID              0
# Gender_Category       0
# Product_Line          0
# Product_Name          0
# Size                510
# Units_Sold            0
# MRP                   0
# Discount_Applied      0
# Revenue               0
# Order_Date          616
# Sales_Channel         0
# Region                0
# Profit                0
# dtype: int64

# %%
Nike_df['Size'].head(10)
# Out:
# 0     M
# 1     M
# 2     M
# 3     L
# 4    XL
# 5     M
# 6     M
# 7     M
# 8    11
# 9     M
# Name: Size, dtype: object

# %%
Nike_df['Size'].unique()
# Out:
# array(['M', 'L', 'XL', '11', nan, '9', '6', '12', '7', '10', '8'],
#       dtype=object)

# %%
Nike_df['Size'].value_counts()
# Out:
# Size
# L     513
# XL    512
# M     478
# 7      86
# 11     77
# 10     76
# 9      68
# 12     61
# 8      60
# 6      59
# Name: count, dtype: int64

# %%
# Nike_df['Size'].fillna(Nike_df['Size'].mode()[0],inplace=True)
# Nike_df['Size'].isnull().sum()

# %%
Nike_df['Order_Date'] = pd.to_datetime(Nike_df['Order_Date'],format='mixed')

# %%
Nike_df['Order_Date'].ffill(inplace=True)
Nike_df['Order_Date'].isnull().sum()
# Out:
# C:\Users\Harsh\AppData\Local\Temp\ipykernel_19860\114281918.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Nike_df['Order_Date'].ffill(inplace=True)
# 0

# %%
Nike_df.isnull().sum()
# Out:
# Order_ID              0
# Gender_Category       0
# Product_Line          0
# Product_Name          0
# Size                510
# Units_Sold            0
# MRP                   0
# Discount_Applied      0
# Revenue               0
# Order_Date            0
# Sales_Channel         0
# Region                0
# Profit                0
# dtype: int64

# %%
Nike_df.loc[55:90]
# Out:
#     Order_ID Gender_Category Product_Line        Product_Name Size  \
# 55      2055             Men   Basketball       Kyrie Flytrap    L
# 56      2056             Men      Running      React Infinity    L
# 57      2048             Men    Lifestyle          Waffle One    M
# 58      2058           Women     Training        Flex Trainer   11
# 59      2059            Kids       Soccer          Phantom GT  NaN
# 60      2060             Men    Lifestyle          Waffle One    L
# 61      2061           Women   Basketball           LeBron 20    L
# 62      2062             Men   Basketball          Air Jordan  NaN
# 63      2063           Women   Basketball          Air Jordan    M
# 64      2064            Kids      Running      React Infinity    L
# 65      2065           Women    Lifestyle          Waffle One   10
# 66      2066             Men       Soccer          Phantom GT   XL
# 67      2067            Kids   Basketball           LeBron 20    L
# ...
