# %% [markdown]
# # File handaling =

# %%
nobal_man = open('Dasrath Manjhi.txt','r')
nobal_man.readline()
# Out:
# 'Born: 14 January 1934, Gehlaur, Bihar Died: 17 August 2007, New Delhi (aged 73)Known As: Mountain Man'

# %%
nobal_man = open('Dasrath Manjhi.txt','r')
nobal_man.readline(10)
# Out:
# 'Born: 14 J'

# %%
nobal_man = open('Dasrath Manjhi.txt','w')
nobal_man.write('''Born: 14 January 1934, Gehlaur, Bihar Died: 17 August 2007, New Delhi '
(aged 73)Known As: Mountain Man''')
nobal_man.close()   # Very important to close because it stores storage for further data,value,text.

# %%
nobal_man = open('Dasrath Manjhi.txt','a')
nobal_man.write('Born: 14 January 1934, Gehlaur, Bihar Died: 17 August 2007, New Delhi (aged 73)Known As: Mountain Man')
nobal_man.close()

# %%
nobal_man = open('Sonam Wangchuk','x')
nobal_man.close()
# x = exclusive creation
# means if the file not exist then creat a file .
# and file already exist the throwh error.

# %%
with open('Dasrath Manjhi.txt','r') as file:
    f = file.read()
    print(f)
# Out:
# Born: 14 January 1934, Gehlaur, Bihar Died: 17 August 2007, New Delhi (aged 73)Known As: Mountain Man

# %%
with open(r'D:\Notepaid\Excel shortcut key.txt') as shortcut: # rlagana hi padega ya fir \ ki place \\ .
    sort_key = shortcut.read()
    print(sort_key)
# Out:
# --------------------Excel  shortcut--------------------------
#
#
# 1.  Alt F4 -  for close the current window for all
# 2.  Alt space & n - To minimize the exe sheet
# 3.  Alt space & r - To return full screen the excel sheet
# 4.  Alt space & x - To maximize the excel sheet.
# 5.  Alt + v + z - To open zoom in and out option in excel .
#     Alt - to show all shortcut key.
#     Alt + E + I + S  - TO SR numbring.(2.14)
#     Alt + H + O + I  - To reduce  the  witdh .
#     Alt =   -  then alt = again to all sum.
#     Alt + I + C  =  To add columns.(2.57)
#     Alt + I + R =  To add row .
#     Alt enter = warp text (means multiple line write in single cell).
#     Alt + H + M + C = TO bild row and column visual..
#
#
#
# 5.  ctrl W   -- To remove current page(sheet) like browser pages.     [1.24hr]
# 6.  ctrl N  - to new worksheet  open
# 7.  ctrl F1 - to show and remove Ribon bar.
# 7.  ctrl down button -  Top to last row.
#     ctrl right button -  Top to last column.
# ...

# %% [markdown]
# # Rename file name

# %%
import os

# %%
nobal_man = open('kataraaa.txt','x')
nobal_man.close()

# %%
import os
os.rename('kataraaa.txt','Kantara.txt')

# %% [markdown]
# # Remove

# %%
os.remove('Kantara.txt')
