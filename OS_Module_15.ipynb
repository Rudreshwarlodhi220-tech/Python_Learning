# %% [markdown]
# # - OS Module -
#
# - The OS module in Python provide a way of using operating system dependent functionality which includes file and directory operation, process management, environment variable and more.
# We can import the OS module using ex .import OS.

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Harsh\Python_all notes\Python_Notes

# %%
os.mkdir('Newfoder') # for creating new folder in system

# %%
os.makedirs(r'New_folder/python/loop') # make folder into folders.

# %%
print(os.path.exists('New_folder'))
# Out:
# True

# %%
if os.path.exists('New_folder'):
    print('True')
else:
    os.mkdir('New_folder/')
# Out:
# True
