# %% [markdown]
# 1. Create a dictionary from two lists
# - Input: keys = ['a','b','c'], values = [1,2,3]
# - Output: {'a': 1, 'b': 2, 'c': 3}

# %%
keys = ['a','b','c']
values = [1,2,7]
dic = {}

for i in range(len(keys)):
    dic[keys[i]] = values[i]

print(dic)
# Out:
# {'a': 1, 'b': 2, 'c': 7}

# %% [markdown]
# तुमने loop for i in range(len(keys)): लगाया है।
# इसका मतलब है कि i की value होगी: 0, 1, 2 (क्योंकि len(keys) = 3)।
#
# जब i = 0 → dic[keys[0]] = values[0] → 'a': 1
#
# जब i = 1 → dic[keys[1]] = values[1] → 'b': 2
#
# जब i = 2 → dic[keys[2]] = values[2] → 'c': 3
#
# 👉 इसलिए values[i] लिखा है ताकि हर key के साथ उसी index का value जुड़ सके।

# %%
keys = ['a','b','c']
values = [1,2,3]

dic = {keys[i]: values[i] for i in range(len(keys))}

print(dic)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %% [markdown]
# 2. Count frequency of each character in a string
# - Input: "banana"
# - Output: {'b':1, 'a':3, 'n':2}

# %%
string = 'banana'
dic = {}

for i in string:
     
    if i not in dic:        
        count =1
        dic[i]=count
    else:
        count+=1
        dic[i] = dic[i] + 1  # yaha jo bhi = ke right side hota hai vo hamesha uski key ki value hoti hai isliye 1+1.

print(dic)
# Out:
# {'b': 1, 'a': 3, 'n': 2}

# %% [markdown]
# 3. Merge two dictionaries
# - Input: {'x':1, 'y':2}, {'z':3}
# - Output: {'x':1, 'y':2, 'z':3}

# %%
Input = {'x':1, 'y':2} 

Input.update({'z':3})
print(Input)
# Out:
# {'x': 1, 'y': 2, 'z': 3}

# %% [markdown]
# 4. Remove a key from a dictionary
# - Input: {'a':1, 'b':2}, remove 'a'
# - Output: {'b':2}

# %%
dic = {'a':1,'b':2}
dic.pop('a')

print(dic)
# Out:
# {'b': 2}

# %% [markdown]
# 5. Find the key with the maximum value
# - Input: {'a':10, 'b':30, 'c':20}
# - Output: 'b'

# %%
dic = {'a':10,'b':30,'c':20}
strr = []
max_num = []
for i,j in dic.items():
    strr.append(i)
    max_num.append(j)

jk = max_num[0]
for i in max_num:
    if jk<i:
        jk = i


print(jk)
# Out:
# 30

# %%
dic = {'a':10,'b':30,'c':20}
strr = ''
max_num = 0

for key,value in dic.items():
    if  max_num < value:
        max_num = value
        strr = key
print(strr,max_num)
# Out:
# b 30

# %% [markdown]
# 6. Find the sum of all dictionary values
# - Input: {'a':1, 'b':2, 'c':3}
# - Output: 6

# %%
dic = {'a':1, 'b':2, 'c':3} 
sum = 0
for i in dic.values():
    sum += i

print(sum)
# Out:
# 6

# %% [markdown]
# 7. Check if a key exists in a dictionary
# - Input: {'a':1, 'b':2}, check 'b'
# - Output: True

# %%
dic = {'a':1,'b':2}

if 'b' in dic:
    print('True')
else:
    print('Falase')
# Out:
# True

# %% [markdown]
# 8. Get all keys from a dictionary
# -  Input: {'x':1, 'y':2}
# - Output: ['x','y']

# %%
dictoi = {'x':1, 'y':2} 
lst = []
for i in dictoi.keys():
    lst.append(i)
print(lst)
# Out:
# ['x', 'y']

# %% [markdown]
# 9. Get all values from a dictionary
# - Input: {'x':1, 'y':2}
# - Output: [1,2]

# %%
dicto = {'x':1, 'y':2} 
lst =  []
#lst = dicto.values()
for i in dicto.values():
    lst.append(i)

print(lst)
# Out:
# [1, 2]

# %% [markdown]
# 10. Convert dictionary values to list
# - Input: {'a':5, 'b':7, 'c':8}
# - Output: [5,7,8]

# %%
dicto ={'a':5, 'b':7, 'c':8}
lst =  []
for i in dicto.values():
    lst.append(i)

print(lst)
# Out:
# [5, 7, 8]

# %% [markdown]
# 11. Find average of dictionary values
# - Input: {'a':10, 'b':20, 'c':30}
# - Output: 20.0

# %%
dicto = {'a':10, 'b':20, 'c':30}
for i in dicto.values():
    if i == 20:
        print(float(i))
# Out:
# 20.0

# %% [markdown]
# 12. Sort a dictionary by its values
# - Input: {'a':3, 'b':1, 'c':2}
# - Output: {'b':1,'c':2,'a':3}

# %%
dicto = {'a':3, 'b':1, 'c':2} 
di_1 = {}
di_2 = {}
di_3 = {}

dic_1 = dicto.popitem()
dic_2 = dicto.popitem()
dic_3 = dicto.popitem()

# %%
dicto = {'a':3, 'b':1, 'c':2} 
second_dic = {}
for i,j in dicto.items():
    second_dic.update({i:j})
    if second_dic.get('a') > j:

    
        print(second_dic)a
# Out:
# {'a': 3, 'b': 1}
# {'a': 3, 'b': 1, 'c': 2}

# %%
dicto = {'a':3, 'b':1, 'c':2} 
second_dic = {}

for i,j in dicto.items():
    second_dic.update({i:j})
print(second_dic )
# Out:
# {'a': 3, 'b': 1, 'c': 2}
