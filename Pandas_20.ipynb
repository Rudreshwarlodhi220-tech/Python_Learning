# %% [markdown]
# # Pandas -
# - Open Sources Package
# - Pandas means Panal(Spreadsheet) Dataset(information).
# - Using Pandas we can Load data, Data manupulation, Data Visualization and Data Analysis .

# %%
import numpy as np
import pandas as pd

# %%
dict1 = {'Name':['Rohan','Manav','Amar','Pawan'],
         'Mark':[56,78,34,77],
         'City':['Indore','Mumbai','Sagar','Bina']
         }

df = pd.DataFrame(dict1)
print(df)
# Out:
#     Name  Mark    City
# 0  Rohan    56  Indore
# 1  Manav    78  Mumbai
# 2   Amar    34   Sagar
# 3  Pawan    77    Bina

# %%
df.to_csv('friends.csv',index = False)   # convert into csv or excel foormat. , index = false ye index noumber ko hata dega.

# %%
df.head(2)  # Top 2 rows.
# Out:
#     Name  Mark    City
# 0  Rohan    56  Indore
# 1  Manav    78  Mumbai

# %%
df.tail(2)    # Botom 2 rows.
# Out:
#     Name  Mark   City
# 2   Amar    34  Sagar
# 3  Pawan    77   Bina

# %%
df.describe()   # describe all the information .
# Out:
#            Mark
# count   4.00000
# mean   61.25000
# std    20.80665
# min    34.00000
# 25%    50.50000
# 50%    66.50000
# 75%    77.25000
# max    78.00000

# %%
harsh = pd.read_csv('D:\Excel folder\employee_data_DEELETE.csv')  # to import csv file It work on jupeter notebook.

harsh

# %%
dict1['Mark'][1] = 66

df
# Out:
#     Name  Mark    City
# 0  Rohan    56  Indore
# 1  Manav    78  Mumbai
# 2   Amar    34   Sagar
# 3  Pawan    77    Bina
